# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\cleaned_all_phones.csv")

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
data.shape
# Out:
# (1512, 22)

# %% [markdown]
# # how many unique mobile brands are there

# %%
brands=data["brand"].unique()

# %%
brands
# Out:
# array(['Huawei', 'LG', 'Xiaomi', 'Sony', 'Oppo', 'Samsung', 'Lenovo',
#        'Apple', 'Google', 'Honor', 'Realme', 'OnePlus', 'Vivo'],
#       dtype=object)

# %%
brands.shape
# Out:
# (13,)

# %% [markdown]
# # what is the avg ram in all mobiles

# %%
data["ram(GB)"].mean()
# Out:
# 6.6838624338624335

# %% [markdown]
# # which phn is having the max battery

# %%
data.loc[data["battery"]==data["battery"].max(),["phone_name","battery"]]
# Out:
#     phone_name  battery
# 573         V6     7250

# %% [markdown]
# # which phn name is having the min battery

# %%
data.loc[data["battery"]==data["battery"].min(),["phone_name","battery"]]
# Out:
#            phone_name  battery
# 62           iPhone 8     1821
# 536  iPhone SE (2020)     1821

# %% [markdown]
# # wt is the max battery capacity in Huawei

# %%
data.loc[data["battery"]==data["battery"].max(),["brand"]].value_counts()
# Out:
# brand
# Honor    1
# dtype: int64

# %% [markdown]
# # which phn brand has the min ram

# %%
data.loc[data["ram(GB)"]==data["ram(GB)"].min(),["brand"]]
# Out:
#        brand
# 27    Huawei
# 28   Samsung
# 69   Samsung
# 133   Huawei
# 182  Samsung
# 230  Samsung
# 236   Huawei
# 244   Xiaomi
# 304  Samsung
# 363       LG
# 550  Samsung

# %%
data.loc[data["ram(GB)"]==data["ram(GB)"].min(),["brand"]].shape
# Out:
# (11, 1)

# %% [markdown]
# # which is the oldest phn announced and also give the date of announcement

# %%
data["announcement_date"]=pd.to_datetime(data["announcement_date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   datetime64[ns]
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
data.loc[data["announcement_date"]==data["announcement_date"].min(),["phone_name","announcement_date"]]
# Out:
#      phone_name announcement_date
# 0  Y6II Compact        2016-09-01

# %% [markdown]
# # how many phns have the android 7 as os

# %%
len(data["os"])
# Out:
# 1512

# %%
len(data["os"]=="Android 7.0")
# Out:
# 1512

# %%
data.loc[data["os"]=="Android 7.0",["phone_name"]].count()
# Out:
# phone_name    33
# dtype: int64

# %% [markdown]
# # which phn has least no. of brand produced

# %%
data["brand"].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %% [markdown]
# # give the phn name and brand name having the costliest phn

# %%
data.loc[data["price(USD)"]==data["price(USD)"].max(),["brand","phone_name","price(USD)"]]
# Out:
#       brand phone_name  price(USD)
# 777  Huawei     P40 4G      2300.0

# %%
data["price(USD)"].max()
# Out:
# 2300.0

# %% [markdown]
# # cheapest phn name and brand name

# %%
data.loc[data["price(USD)"]==data["price(USD)"].min(),["brand","phone_name","price(USD)"]]
# Out:
#       brand phone_name  price(USD)
# 452  Realme        C2s        40.0

# %%
data["price(USD)"].min()
# Out:
# 40.0

# %% [markdown]
# # how many phn supports
#    # 1. 4k video
#    # 2. 84 video
#    # 3. 2k video

# %%
data.loc[data["video_4K"]]
# Out:
#              phone_name    brand           os  inches resolution  battery  \
# 4                   P10   Huawei  Android 7.0    5.10  1080x1920     3200
# 7              P10 Plus   Huawei  Android 7.0    5.50  1440x2560     3750
# 11           Xperia XZs     Sony  Android 7.1    5.20  1080x1920     2900
# 12    Xperia XZ Premium     Sony  Android 7.1    5.46  3840x2160     3230
# 15              F3 Plus     Oppo    Android 6    6.00  1080x1920     4000
# ...                 ...      ...          ...     ...        ...      ...
# 1505    Redmi K60 Ultra   Xiaomi   Android 13    6.67  1220x2712     5000
# 1506          Ace 2 Pro  OnePlus   Android 13    6.74  1240x2772     5000
# 1509                GT5   Realme   Android 13    6.74  1240x2772     5240
# 1510           GT5 240W   Realme   Android 13    6.74  1240x2772     4600
# 1511   vivo iQOO Z7 Pro     Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.loc[data["video_8K"]]
# Out:
#                phone_name    brand          os  inches resolution  battery  \
# 466         Galaxy S20 5G  Samsung  Android 10    6.20  1440x3200     4000
# 467        Galaxy S20+ 5G  Samsung  Android 10    6.70  1440x3200     4500
# 468      Galaxy S20 Ultra  Samsung  Android 10    6.90  1440x3200     5000
# 470   Galaxy S20 Ultra 5G  Samsung  Android 10    6.90  1440x3200     5000
# 471           Galaxy S20+  Samsung  Android 10    6.70  1440x3200     4500
# ...                   ...      ...         ...     ...        ...      ...
# 1447       vivo iQOO Neo8     Vivo  Android 13    6.78  1260x2800     5000
# 1476        vivo iQOO 11S     Vivo  Android 13    6.78  1440x3200     4700
# 1497       Galaxy Z Fold5  Samsung  Android 13    7.60  1812x2176     4400
# 1504           Mix Fold 3   Xiaomi  Android 13    8.03  1916x2160     4800
# 1505      Redmi K60 Ultra   Xiaomi  Android 13    6.67  1220x2712     5000
#
# ...

# %%
data.loc[data["video_1080p"]]
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# 5           Xperia XA1    Sony  Android 7.0    5.00   720x1280     2300
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.loc[data["price(USD)"].min(),["brand","phone_name","price(USD)"]]
# Out:
# brand                  Samsung
# phone_name    Galaxy J5 (2017)
# price(USD)                80.0
# Name: 40, dtype: object
